# %% [markdown]
# # Laboratorio 1

# %% [markdown]
# ## Desarrollo de una herramienta analítica usando recursos nativos de Python

# %% [markdown]
# Para el desarrollo de esta actividad debes utilizar únicamente recursos nativos de Python (puedes usar librerías como `math` y `random`). Está prohibido el uso de librerías externas, a excepción de `matplotlib`. Te recomendamos leer por completo el enunciado del laboratorio antes de comenzar, de forma que tengas claro el propósito global de la actividad y puedas desarrollar tu solución apuntando a él desde el inicio.

# %% [markdown]
# En algunas de las misiones encontrarás: una **versión base**, la cual indica el requerimiento mínimo de la misión; una **versión completa**, la cual indica mejoras deseables o complementos a la **versión base**. Un desarrollo aceptable del laboratorio debe satisfacer la **versión base** y un desarrollo correcto del laboratorio debe satisfacer la **versión completa**. Cumplir con el desarrollo de la **versión completa** desde un inicio hará más sencillas las misiones siguientes.

# %% [markdown]
# Al desarrollar este laboratorio pondrás a prueba tus habilidades para:
#
# 1. Identificar y abordar preguntas de negocio y de *analytics*.
# 2. Leer datos desde archivos y almacenarlos en estructuras de Python.
# 3. Crear y llamar funciones.
# 4. Implementar condicionales diferenciando `if`, `elif` y `else`.
# 5. Implementar ciclos diferenciando el propósito de `for` y `while`.

# %% [markdown]
# ## Contexto: exploración del potencial para asignar becas Unialpes

# %% [markdown]
# La Universidad ean se ha caracterizado por su compromiso con la generación de impacto en la sociedad a través de diferentes programas de becas. Programas como Becas para los Mejores, entre otros, han sido revolucionarios al permitir que estudiantes de bajos recursos puedan acceder a una de las universidades más prestigiosas del país.

# %% [markdown]
# Actualmente, la universidad quiere evaluar el potencial impacto que tendrían algunos programas de acción afirmativa para asignación de becas, con base en información demográfica que ha obtenido a través de encuestas a personas interesadas en becas. Se cuenta con información respecto a la edad, género, estado civil, estrato socioeconómico, región de proveniencia, desempeño académico y nivel de escolaridad de las personas encuestadas. Los encargados de diseñar el programa saben que utilizar criterios basados en este tipo de variables es un tema sensible, pero es necesario si se quieren focalizar las oportunidades en poblaciones menos representadas.

# %% [markdown]
# El objetivo de este laboratorio es crear una herramienta computacional que permita a un tomador de decisiones explorar qué efecto podría tener el uso de diferentes reglas para seleccionar a los beneficiarios de las becas. Puntualmente, se espera que, para distintas reglas de selección (ej., pertenecer a cierta región, rango de edad, etc.), la herramienta ofrezca una caracterización de los potenciales beneficiarios de las becas (a partir de estadísticas descriptivas y visualizaciones), de forma que exista un sustento para elegir la regla de selección adecuada.

# %% [markdown]
# ## Fase 1: obtener e inspeccionar archivos

# %% [markdown]
# Los datos de encuestas fueron obtenidos como parte de un trabajo de campo y, por limitaciones tecnológicas, solo se cuenta con la información en archivos de texto plano (`.txt`). Cada archivo corresponde a uno de los atributos antes mencionados y están estructurados de forma que todos relacionan a las personas encuestadas en el mismo orden (i.e., en cada archivo la primera línea corresponde a un dato de la primera persona encuestada, la segunda línea corresponde a un dato de la segunda persona encuestada, etc.).

# %% [markdown]
# Los archivos con los que cuentas son:
#
# * `"edad.txt"`: un archivo con la edad de cada persona encuestada;
# * `"escolaridad.txt"`: un archivo con el nivel de escolaridad de cada persona encuestada;
# * `"estado_civil.txt"`: un archivo con el estado civil de cada persona encuestada;
# * `"estrato.txt"`: un archivo con el estrato socioeconómico de cada persona encuestada;
# * `"genero.txt"`: un archivo con el género de cada persona encuestada;
# * `"promedio.txt"`: un archivo con el promedio académico de cada persona encuestada;
# * `"region.txt"`: un archivo con la región de proveniencia de cada persona encuestada.

# %% [markdown]
# ### Misión 1

# %% [markdown]
# **Versión base**: utiliza métodos de lectura de archivos para guardar la información de cada archivo en una estructura de datos de Python, de manera que se respete el orden y la categoría de los datos.

# %% [markdown]
# **Versión completa**: escribe una función que sea capaz de ejecutar la **versión base** y llámala dentro de un ciclo para automatizar la lectura de los archivos.

# %%
edadFile = open("Archivos/edad.txt","r",encoding="UTF-8")
escolaridadFile = open("Archivos/escolaridad.txt","r",encoding="UTF-8")
eCivilFile = open("Archivos/estado_civil.txt","r",encoding="UTF-8")
estratoFile = open("Archivos/estrato.txt","r",encoding="UTF-8")
generoFile = open("Archivos/genero.txt","r",encoding="UTF-8")
promedioFile = open("Archivos/promedio.txt","r",encoding="UTF-8")
regionFile = open("Archivos/region.txt","r",encoding="UTF-8")
edad=[]
escolaridad=[]
estado_civil=[]
estrato=[]
genero=[]
promedio=[]
region=[]

for i in edadFile:
    edad.append(i.strip())

for i in escolaridadFile:
    escolaridad.append(i.strip())

for i in eCivilFile:
    estado_civil.append(i.strip())

for i in estratoFile:
    estrato.append(i.strip())

for i in generoFile:
    genero.append(i.strip())

for i in promedioFile:
    promedio.append(i.strip())

for i in regionFile:
    region.append(i.strip())

contBecados=0
for j in range(500):

      print(f"Persona #{j+1}: {edad[j]},{escolaridad[j]},{estado_civil[j]},{estrato[j]},{genero[j]},{promedio[j]},{region[j]}")
# Out:
# Persona #1: 36,Secundaria,casada,5,masculino,2.4,Region_1
# Persona #2: 66,Profesional,divorciada,1,masculino,0.9,Region_1
# Persona #3: 24,Secundaria,divorciada,3,femenino,3.2,Region_2
# Persona #4: 55,Secundaria,casada,3,masculino,2.1,Region_2
# Persona #5: 26,Secundaria,divorciada,2,otro,2.1,Region_3
# Persona #6: 69,Secundaria,divorciada,3,no binario,2.0,Region_4
# Persona #7: 79,Secundaria,casada,4,masculino,2.7,Region_5
# Persona #8: 54,Secundaria,casada,2,femenino,4.9,Region_1
# Persona #9: 51,Secundaria,soltera,2,femenino,2.1,Region_4
# Persona #10: 80,Profesional,soltera,3,masculino,4.5,Region_1
# Persona #11: 30,Secundaria,soltera,2,femenino,3.0,Region_4
# Persona #12: 64,Primaria,casada,2,femenino,3.0,Region_2
# Persona #13: 40,Secundaria,casada,2,femenino,3.5,Region_4
# Persona #14: 53,Secundaria,casada,3,femenino,1.8,Region_2
# Persona #15: 47,Secundaria,divorciada,1,no binario,1.2,Region_2
# Persona #16: 24,Secundaria,divorciada,1,femenino,0.1,Region_2
# Persona #17: 76,Secundaria,casada,3,masculino,1.0,Region_4
# Persona #18: 65,Secundaria,divorciada,2,femenino,3.9,Region_4
# Persona #19: 38,Secundaria,soltera,3,masculino,2.9,Region_1
# Persona #20: 37,Profesional,casada,2,masculino,3.0,Region_1
# Persona #21: 71,Secundaria,soltera,3,femenino,3.0,Region_2
# Persona #22: 51,Secundaria,soltera,1,femenino,3.0,Region_2
# Persona #23: 51,Secundaria,casada,2,no binario,4.3,Region_4
# Persona #24: 33,Secundaria,casada,2,masculino,2.3,Region_4
# Persona #25: 24,Profesional,casada,3,femenino,2.6,Region_1
# Persona #26: 71,Secundaria,divorciada,1,masculino,2.3,Region_4
# Persona #27: 78,Secundaria,soltera,3,femenino,3.0,Region_1
# Persona #28: 75,Secundaria,soltera,3,femenino,2.8,Region_4
# Persona #29: 38,Secundaria,soltera,3,femenino,1.0,Region_4
# Persona #30: 49,Secundaria,divorciada,1,femenino,2.9,Region_1
# Persona #31: 49,Secundaria,casada,1,femenino,3.7,Region_4
# Persona #32: 53,Secundaria,divorciada,2,no binario,3.2,Region_4
# Persona #33: 62,Secundaria,casada,2,masculino,3.3,Region_4
# Persona #34: 26,Secundaria,casada,2,masculino,3.9,Region_1
# Persona #35: 67,Secundaria,casada,2,no binario,2.6,Region_1
# Persona #36: 68,Profesional,divorciada,2,masculino,2.4,Region_2
# Persona #37: 70,Secundaria,divorciada,2,femenino,3.9,Region_4
# Persona #38: 57,Primaria,divorciada,2,femenino,1.8,Region_4
# Persona #39: 47,Secundaria,casada,5,femenino,3.3,Region_4
# Persona #40: 30,Maestria,soltera,1,masculino,2.1,Region_3
# Persona #41: 44,Secundaria,divorciada,2,masculino,1.9,Region_2
# Persona #42: 22,Secundaria,soltera,2,masculino,1.7,Region_2
# Persona #43: 30,Secundaria,divorciada,3,masculino,2.5,Region_4
# Persona #44: 64,Secundaria,soltera,2,masculino,2.9,Region_2
# Persona #45: 21,Secundaria,soltera,2,femenino,1.5,Region_3
# Persona #46: 54,Secundaria,casada,3,femenino,4.1,Region_1
# Persona #47: 35,Secundaria,casada,2,no binario,0.9,Region_1
# Persona #48: 52,Secundaria,divorciada,2,femenino,3.0,Region_4
# Persona #49: 27,Secundaria,casada,2,femenino,2.3,Region_4
# Persona #50: 20,Secundaria,soltera,3,masculino,4.5,Region_5
# Persona #51: 59,Secundaria,soltera,3,femenino,2.8,Region_3
# Persona #52: 40,Profesional,casada,2,femenino,3.8,Region_4
# Persona #53: 23,Profesional,soltera,3,masculino,3.3,Region_2
# Persona #54: 58,Secundaria,casada,4,femenino,3.9,Region_4
# Persona #55: 71,Secundaria,viuda,2,masculino,3.0,Region_2
# Persona #56: 77,Secundaria,divorciada,3,masculino,2.7,Region_2
# Persona #57: 70,Profesional,viuda,1,femenino,2.4,Region_4
# Persona #58: 31,Secundaria,casada,2,femenino,1.1,Region_4
# Persona #59: 19,Secundaria,divorciada,1,masculino,2.6,Region_3
# Persona #60: 31,Secundaria,divorciada,2,masculino,3.1,Region_4
# Persona #61: 75,Primaria,casada,3,femenino,4.9,Region_4
# Persona #192: 21,Secundaria,soltera,2,femenino,3.0,Region_2
# Persona #193: 55,Secundaria,casada,3,femenino,1.3,Region_2
# Persona #194: 50,Secundaria,casada,1,femenino,3.9,Region_4
# Persona #195: 46,Secundaria,casada,2,masculino,3.8,Region_3
# Persona #196: 75,Secundaria,casada,4,otro,3.1,Region_5
# Persona #197: 54,Profesional,soltera,5,masculino,2.4,Region_4
# Persona #198: 80,Secundaria,soltera,1,femenino,2.2,Region_4
# Persona #199: 61,Maestria,casada,3,masculino,2.4,Region_3
# Persona #200: 78,Secundaria,casada,2,masculino,2.4,Region_4
# Persona #201: 21,Secundaria,soltera,2,femenino,0.9,Region_2
# Persona #202: 76,Profesional,casada,1,masculino,3.4,Region_1
# Persona #203: 61,Secundaria,divorciada,3,masculino,3.7,Region_4
# Persona #204: 67,Secundaria,casada,2,masculino,2.8,Region_1
# Persona #205: 66,Profesional,casada,3,femenino,2.5,Region_4
# Persona #206: 27,Profesional,divorciada,3,masculino,2.1,Region_3
# Persona #207: 74,Profesional,casada,4,femenino,2.3,Region_1
# Persona #208: 21,Profesional,casada,2,femenino,4.9,Region_1
# Persona #209: 21,Profesional,casada,2,femenino,1.3,Region_4
# Persona #210: 55,Secundaria,casada,1,femenino,2.5,Region_1
# Persona #211: 45,Profesional,casada,3,femenino,3.6,Region_1
# Persona #212: 21,Profesional,casada,2,masculino,0.2,Region_4
# Persona #213: 22,Maestria,casada,2,masculino,3.0,Region_1
# Persona #214: 30,Secundaria,divorciada,1,femenino,4.1,Region_4
# Persona #215: 64,Secundaria,casada,1,masculino,3.2,Region_3
# Persona #216: 78,Secundaria,soltera,3,masculino,2.3,Region_4
# Persona #217: 52,Maestria,soltera,1,femenino,2.7,Region_2
# Persona #218: 61,Secundaria,divorciada,1,femenino,2.6,Region_2
# Persona #219: 19,Secundaria,casada,2,femenino,2.9,Region_4
# Persona #220: 53,Secundaria,casada,3,masculino,1.8,Region_4
# Persona #221: 43,Secundaria,divorciada,4,femenino,2.9,Region_5
# Persona #222: 66,Profesional,divorciada,2,masculino,2.0,Region_3
# Persona #223: 34,Profesional,soltera,2,masculino,4.4,Region_1
# Persona #224: 43,Secundaria,soltera,2,femenino,2.4,Region_4
# Persona #225: 70,Secundaria,soltera,3,femenino,3.3,Region_1
# Persona #226: 27,Profesional,divorciada,2,femenino,1.0,Region_4
# Persona #227: 53,Profesional,divorciada,3,femenino,2.1,Region_4
# Persona #228: 40,Secundaria,casada,3,no binario,2.1,Region_1
# Persona #229: 32,Secundaria,casada,3,femenino,3.0,Region_3
# Persona #230: 33,Secundaria,soltera,2,femenino,2.4,Region_4
# Persona #231: 63,Profesional,soltera,1,femenino,3.0,Region_1
# Persona #232: 69,Secundaria,divorciada,3,no binario,1.3,Region_2
# Persona #233: 22,Profesional,divorciada,1,femenino,1.4,Region_4
# Persona #234: 58,Secundaria,soltera,3,masculino,3.2,Region_1
# Persona #235: 23,Secundaria,soltera,1,femenino,3.3,Region_2
# Persona #279: 35,Secundaria,casada,3,femenino,2.9,Region_2
# Persona #280: 29,Profesional,soltera,1,masculino,0.7,Region_4
# Persona #281: 36,Secundaria,soltera,2,femenino,1.2,Region_5
# Persona #282: 53,Secundaria,casada,1,masculino,4.0,Region_1
# Persona #283: 22,Secundaria,soltera,4,femenino,1.9,Region_1
# Persona #284: 28,Secundaria,divorciada,1,no binario,4.8,Region_1
# Persona #285: 61,Secundaria,divorciada,3,femenino,1.4,Region_4
# Persona #286: 40,Secundaria,casada,4,no binario,2.7,Region_1
# Persona #287: 57,Primaria,soltera,1,femenino,2.7,Region_3
# Persona #288: 20,Secundaria,soltera,1,femenino,4.3,Region_2
# Persona #289: 43,Secundaria,soltera,1,femenino,0.6,Region_1
# Persona #290: 54,Secundaria,casada,1,masculino,4.0,Region_2
# Persona #291: 54,Profesional,casada,1,masculino,1.1,Region_2
# Persona #292: 18,Profesional,casada,3,masculino,3.7,Region_4
# Persona #293: 75,Secundaria,divorciada,3,femenino,2.3,Region_4
# Persona #294: 45,Secundaria,divorciada,3,femenino,2.1,Region_4
# Persona #295: 39,Primaria,divorciada,3,femenino,3.7,Region_2
# Persona #296: 41,Profesional,soltera,2,masculino,3.0,Region_4
# Persona #297: 56,Secundaria,casada,5,femenino,2.4,Region_4
# Persona #298: 71,Profesional,soltera,3,femenino,2.2,Region_4
# Persona #299: 54,Secundaria,soltera,2,femenino,3.0,Region_2
# Persona #300: 58,Maestria,casada,1,masculino,3.0,Region_4
# Persona #301: 79,Secundaria,casada,3,femenino,3.5,Region_2
# Persona #302: 30,Secundaria,casada,4,masculino,0.9,Region_5
# Persona #303: 75,Secundaria,viuda,3,no binario,3.5,Region_1
# Persona #304: 45,Secundaria,soltera,2,femenino,2.7,Region_3
# Persona #305: 38,Secundaria,divorciada,2,femenino,3.0,Region_1
# Persona #306: 55,Secundaria,soltera,1,masculino,3.7,Region_1
# Persona #307: 24,Primaria,casada,3,femenino,1.0,Region_3
# Persona #308: 68,Profesional,casada,3,femenino,3.0,Region_2
# Persona #309: 30,Secundaria,divorciada,2,femenino,4.4,Region_4
# Persona #310: 24,Profesional,divorciada,1,femenino,0.9,Region_2
# Persona #311: 52,Secundaria,casada,3,femenino,2.7,Region_4
# Persona #312: 29,Profesional,soltera,3,masculino,3.6,Region_1
# Persona #313: 76,Profesional,soltera,3,masculino,2.5,Region_2
# Persona #314: 25,Profesional,soltera,1,no binario,2.2,Region_2
# Persona #315: 58,Secundaria,soltera,2,femenino,3.6,Region_1
# Persona #316: 65,Profesional,soltera,2,masculino,1.9,Region_4
# Persona #317: 53,Profesional,casada,3,femenino,3.1,Region_4
# Persona #318: 64,Secundaria,soltera,1,no binario,0.2,Region_2
# Persona #319: 32,Profesional,soltera,1,femenino,3.1,Region_4
# Persona #320: 74,Profesional,soltera,3,masculino,4.0,Region_4
# Persona #321: 18,Secundaria,casada,4,masculino,2.3,Region_3
# Persona #322: 52,Maestria,viuda,1,femenino,3.8,Region_1
# Persona #323: 48,Profesional,divorciada,2,femenino,1.3,Region_3
# Persona #324: 65,Profesional,casada,3,femenino,3.5,Region_4
# Persona #325: 42,Secundaria,divorciada,4,femenino,1.2,Region_2
# Persona #326: 77,Secundaria,viuda,3,femenino,2.6,Region_2
# Persona #327: 31,Profesional,casada,3,femenino,3.2,Region_4
# Persona #328: 63,Secundaria,soltera,3,masculino,2.6,Region_1
# Persona #329: 35,Profesional,casada,2,femenino,1.9,Region_4
# Persona #330: 48,Secundaria,soltera,2,masculino,3.0,Region_1
# Persona #331: 71,Primaria,casada,2,masculino,3.7,Region_1
# Persona #332: 48,Secundaria,divorciada,1,femenino,3.6,Region_4
# Persona #333: 70,Secundaria,casada,3,masculino,1.1,Region_2
# Persona #334: 57,Primaria,divorciada,1,femenino,2.8,Region_4
# Persona #335: 32,Primaria,soltera,1,masculino,2.0,Region_4
# Persona #336: 45,Maestria,casada,3,femenino,3.2,Region_4
# Persona #337: 68,Secundaria,casada,2,masculino,3.5,Region_1
# Persona #338: 23,Profesional,divorciada,2,femenino,4.0,Region_2
# Persona #339: 26,Secundaria,soltera,2,masculino,3.6,Region_1
# Persona #340: 37,Secundaria,soltera,3,masculino,2.3,Region_1
# Persona #341: 34,Secundaria,soltera,2,femenino,3.0,Region_4
# Persona #342: 27,Secundaria,casada,2,masculino,3.6,Region_4
# Persona #343: 49,Profesional,casada,2,femenino,1.9,Region_3
# Persona #344: 57,Secundaria,divorciada,3,femenino,0.6,Region_2
# Persona #345: 42,Secundaria,soltera,2,masculino,2.0,Region_1
# Persona #346: 67,Secundaria,casada,2,femenino,0.6,Region_2
# Persona #347: 70,Secundaria,soltera,2,femenino,0.9,Region_4
# Persona #348: 59,Profesional,divorciada,1,no binario,3.3,Region_2
# Persona #349: 29,Secundaria,soltera,3,femenino,2.1,Region_1
# Persona #350: 20,Secundaria,soltera,2,masculino,2.7,Region_1
# Persona #351: 42,Secundaria,divorciada,4,femenino,2.5,Region_4
# Persona #352: 18,Secundaria,divorciada,5,masculino,2.9,Region_4
# Persona #353: 48,Primaria,casada,2,femenino,3.5,Region_4
# Persona #354: 41,Secundaria,casada,2,femenino,2.9,Region_4
# Persona #355: 77,Secundaria,soltera,5,masculino,1.6,Region_4
# Persona #356: 68,Maestria,soltera,2,femenino,4.4,Region_2
# Persona #357: 79,Secundaria,divorciada,2,femenino,3.9,Region_1
# Persona #358: 49,Secundaria,casada,1,masculino,3.5,Region_4
# Persona #359: 24,Secundaria,casada,3,masculino,3.2,Region_1
# Persona #360: 24,Secundaria,casada,1,femenino,2.0,Region_1
# Persona #361: 23,Profesional,soltera,5,femenino,2.2,Region_2
# Persona #362: 73,Profesional,divorciada,1,no binario,4.0,Region_2
# Persona #363: 27,Secundaria,casada,3,masculino,2.9,Region_4
# Persona #364: 32,Secundaria,casada,1,femenino,4.9,Region_2
# Persona #365: 80,Secundaria,soltera,4,masculino,2.6,Region_3
# Persona #366: 39,Profesional,casada,3,masculino,2.2,Region_4
# Persona #410: 58,Secundaria,divorciada,2,femenino,4.5,Region_1
# Persona #411: 22,Secundaria,casada,2,masculino,2.0,Region_3
# Persona #412: 23,Secundaria,divorciada,3,femenino,1.0,Region_2
# Persona #413: 74,Secundaria,soltera,1,masculino,1.0,Region_1
# Persona #414: 38,Secundaria,soltera,2,no binario,2.9,Region_4
# Persona #415: 31,Primaria,casada,3,femenino,1.5,Region_4
# Persona #416: 39,Secundaria,soltera,2,femenino,1.2,Region_4
# Persona #417: 55,Secundaria,casada,3,masculino,3.2,Region_1
# Persona #418: 18,Secundaria,casada,2,femenino,0.2,Region_5
# Persona #419: 66,Primaria,casada,3,masculino,2.1,Region_2
# Persona #420: 30,Secundaria,casada,2,masculino,2.5,Region_4
# Persona #421: 57,Secundaria,casada,3,masculino,1.9,Region_1
# Persona #422: 28,Secundaria,divorciada,1,masculino,2.9,Region_1
# Persona #423: 50,Secundaria,soltera,1,masculino,4.2,Region_3
# Persona #424: 24,Secundaria,casada,3,no binario,0.5,Region_4
# Persona #425: 76,Secundaria,divorciada,2,masculino,0.2,Region_1
# Persona #426: 18,Secundaria,casada,2,masculino,0.6,Region_2
# Persona #427: 44,Profesional,divorciada,2,femenino,3.1,Region_2
# Persona #428: 80,Primaria,casada,1,no binario,3.1,Region_1
# Persona #429: 54,Profesional,casada,3,masculino,4.2,Region_1
# Persona #430: 43,Profesional,soltera,3,femenino,2.7,Region_2
# Persona #431: 50,Secundaria,casada,2,femenino,3.0,Region_2
# Persona #432: 79,Secundaria,casada,5,masculino,1.0,Region_1
# Persona #433: 67,Secundaria,soltera,2,masculino,2.5,Region_4
# Persona #434: 63,Secundaria,casada,3,femenino,4.0,Region_4
# Persona #435: 53,Secundaria,soltera,1,masculino,4.0,Region_4
# Persona #436: 71,Secundaria,casada,1,masculino,0.3,Region_4
# Persona #437: 19,Secundaria,casada,3,masculino,0.3,Region_4
# Persona #438: 38,Secundaria,soltera,3,masculino,2.9,Region_4
# Persona #439: 53,Profesional,casada,2,no binario,2.1,Region_4
# Persona #440: 65,Profesional,casada,3,femenino,2.0,Region_4
# Persona #441: 20,Secundaria,soltera,2,masculino,2.5,Region_2
# Persona #442: 45,Secundaria,divorciada,1,masculino,1.1,Region_1
# Persona #443: 25,Maestria,casada,3,femenino,3.6,Region_4
# Persona #444: 75,Secundaria,soltera,3,masculino,3.1,Region_4
# Persona #445: 66,Profesional,soltera,1,femenino,3.1,Region_1
# Persona #446: 25,Maestria,casada,2,femenino,1.7,Region_1
# Persona #447: 24,Secundaria,divorciada,2,masculino,3.0,Region_4
# Persona #448: 33,Secundaria,casada,2,femenino,3.5,Region_1
# Persona #449: 43,Profesional,casada,3,femenino,1.3,Region_4
# Persona #450: 66,Secundaria,casada,2,femenino,1.7,Region_2
# Persona #451: 33,Profesional,divorciada,3,femenino,3.4,Region_4
# Persona #452: 46,Secundaria,soltera,1,femenino,3.2,Region_1
# Persona #453: 53,Secundaria,casada,2,masculino,4.5,Region_1
# Persona #454: 36,Profesional,casada,3,femenino,4.2,Region_4
# Persona #455: 50,Secundaria,casada,3,masculino,4.1,Region_4
# Persona #456: 76,Secundaria,soltera,1,femenino,3.5,Region_4
# Persona #457: 80,Secundaria,divorciada,2,otro,3.0,Region_5
# Persona #458: 74,Profesional,soltera,1,masculino,0.1,Region_2
# Persona #459: 64,Secundaria,casada,2,masculino,3.8,Region_1
# Persona #460: 22,Profesional,divorciada,2,no binario,0.2,Region_1
# Persona #461: 41,Secundaria,soltera,1,femenino,3.4,Region_4
# Persona #462: 20,Profesional,casada,5,femenino,2.0,Region_4
# Persona #463: 75,Maestria,viuda,1,femenino,3.3,Region_4
# Persona #464: 54,Secundaria,casada,2,masculino,1.9,Region_2
# Persona #465: 72,Secundaria,casada,3,masculino,0.7,Region_4
# Persona #466: 38,Secundaria,casada,2,masculino,1.3,Region_1
# Persona #467: 24,Secundaria,soltera,1,femenino,3.7,Region_4
# Persona #468: 67,Secundaria,soltera,3,no binario,3.5,Region_4
# Persona #469: 32,Secundaria,casada,1,femenino,2.3,Region_4
# Persona #470: 50,Secundaria,viuda,3,femenino,2.7,Region_4
# Persona #471: 35,Secundaria,divorciada,3,femenino,3.4,Region_4
# Persona #472: 21,Secundaria,soltera,3,masculino,4.9,Region_2
# Persona #473: 54,Profesional,divorciada,3,masculino,3.7,Region_2
# Persona #474: 64,Secundaria,casada,2,masculino,1.8,Region_4
# Persona #475: 29,Secundaria,casada,2,masculino,2.4,Region_4
# Persona #476: 29,Secundaria,soltera,2,masculino,3.2,Region_4
# Persona #477: 38,Secundaria,casada,2,masculino,0.6,Region_1
# Persona #478: 47,Secundaria,divorciada,3,masculino,3.4,Region_4
# Persona #479: 27,Secundaria,casada,2,femenino,4.6,Region_5
# Persona #480: 73,Secundaria,casada,3,femenino,3.2,Region_4
# Persona #481: 26,Secundaria,viuda,1,masculino,2.2,Region_1
# Persona #482: 69,Secundaria,soltera,4,femenino,2.2,Region_2
# Persona #483: 35,Secundaria,divorciada,2,masculino,3.5,Region_4
# Persona #484: 70,Secundaria,divorciada,3,masculino,2.2,Region_1
# Persona #485: 25,Profesional,soltera,3,femenino,1.4,Region_2
# Persona #486: 19,Secundaria,soltera,2,femenino,0.1,Region_4
# Persona #487: 80,Secundaria,soltera,2,femenino,3.1,Region_1
# Persona #488: 60,Primaria,soltera,3,femenino,0.2,Region_2
# Persona #489: 39,Secundaria,soltera,3,masculino,3.3,Region_5
# Persona #490: 76,Secundaria,casada,1,masculino,3.7,Region_4
# Persona #491: 34,Secundaria,casada,3,masculino,2.0,Region_1
# Persona #492: 59,Profesional,casada,2,masculino,4.9,Region_4
# Persona #493: 49,Profesional,casada,2,masculino,3.4,Region_1
# Persona #494: 23,Secundaria,divorciada,1,masculino,0.8,Region_1
# Persona #495: 34,Secundaria,soltera,1,masculino,2.4,Region_4
# Persona #496: 23,Secundaria,casada,5,femenino,2.1,Region_4
# Persona #497: 24,Secundaria,viuda,1,femenino,2.9,Region_1
# Persona #498: 50,Profesional,casada,1,no binario,2.1,Region_1
# Persona #499: 54,Secundaria,divorciada,2,femenino,2.7,Region_1
# Persona #500: 66,Secundaria,casada,2,femenino,3.0,Region_2

# %% [markdown]
# ### Misión 2

# %% [markdown]
# **Versión base**: calcula estadísticas descriptivas básicas (por lo menos, media/mediana y varianza/desviación) para cada variable relevante en el contexto del problema y repórtalas concluyendo acerca de las principales características de los datos.

# %% [markdown]
# **Versión completa**: complementa la **versión base** con visualizaciones informativas sobre los datos (ej., histogramas, gráficos de dispersión, boxplots, etc.), relevantes para el problema.

# %%
edadFile = open("Archivos/edad.txt","r",encoding="UTF-8")
escolaridadFile = open("Archivos/escolaridad.txt","r",encoding="UTF-8")
eCivilFile = open("Archivos/estado_civil.txt","r",encoding="UTF-8")
estratoFile = open("Archivos/estrato.txt","r",encoding="UTF-8")
generoFile = open("Archivos/genero.txt","r",encoding="UTF-8")
promedioFile = open("Archivos/promedio.txt","r",encoding="UTF-8")
regionFile = open("Archivos/region.txt","r",encoding="UTF-8")
edad=[]
escolaridad=[]
estado_civil=[]
estrato=[]
genero=[]
promedio=[]
region=[]

for i in edadFile:
    edad.append(i.strip())


for i in escolaridadFile:
    escolaridad.append(i.strip())
    
for i in eCivilFile:
    estado_civil.append(i.strip())

for i in estratoFile:
    estrato.append(i.strip())

for i in generoFile:
    genero.append(i.strip())

for i in promedioFile:
    promedio.append(i.strip())

for i in regionFile:
    region.append(i.strip())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\user\OneDrive\Documentos\GitHub\Talleres_de_algoritmos\LABORATORIO - Enunciado\LABORATORIO - Enunciado.ipynb Celda 20 in <cell line: 41>()
#      <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Documentos/GitHub/Talleres_de_algoritmos/LABORATORIO%20-%20Enunciado/LABORATORIO%20-%20Enunciado.ipynb#X25sZmlsZQ%3D%3D?line=35'>36</a>     region.append(i.strip())
#      <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Documentos/GitHub/Talleres_de_algoritmos/LABORATORIO%20-%20Enunciado/LABORATORIO%20-%20Enunciado.ipynb#X25sZmlsZQ%3D%3D?line=39'>40</a> int = edad
# ---> <a href='vscode-notebook-cell:/c%3A/Users/user/OneDrive/Documentos/GitHub/Talleres_de_algoritmos/LABORATORIO%20-%20Enunciado/LABORATORIO%20-%20Enunciado.ipynb#X25sZmlsZQ%3D%3D?line=40'>41</a> print(sum(edad))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Referencias

# %% [markdown]
# * Discriminación Positiva<br>
# https://es.wikipedia.org/wiki/Discriminaci%C3%B3n_positiva
# * Análisis de formulación del programa “Ser Pilo Paga”<br>
# https://repository.urosario.edu.co/handle/10336/12526
# * La acción afirmativa en la Universidad de los Andes: El caso del programa "Oportunidades para talentos nacionales"<br> http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0123-885X2004000300005
# * Acción afirmativa y equidad: un análisis desde la propuesta de Thomas Nagel<br>
# http://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S2007-24062016000200049

# %% [markdown]
# ## Créditos

# %% [markdown]
# __Autores__: Camilo Hernando Gómez Castro, Alejandro Mantilla Redondo, Diego Alejandro Cely Gómez.
#
# __Fecha última actualización__: 11/07/2022
